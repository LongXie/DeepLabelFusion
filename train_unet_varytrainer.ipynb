# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import importlib
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

from model.model import get_model
from utils.gen_utils import get_logger

from datasets.Prisma3TT1T2Dataset import get_train_loaders
from model.losses import get_loss_criterion
from model.metrics import get_evaluation_metric
from model.trainer import get_trainer
from model.utils import get_number_of_learnable_parameters, get_tensorboard_formatter

# Create main logger
logger = get_logger('VaryTrainer')

# Top level configuration
import yaml
import config.runconfig as runconfig 
c = runconfig.Config_Run()

# Load and log experiment configuration
config = yaml.safe_load(open(c.config_file, 'r'))

# Set up GPU if available
DEFAULT_DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"
device = config.get('device', DEFAULT_DEVICE)
config['device'] = torch.device(device)
torch.cuda.set_device(0)
print(config['device'])
# Out:
# cuda:0

# %%
def _create_optimizer(config, model):
    assert 'optimizer' in config, 'Cannot find optimizer configuration'
    optimizer_config = config['optimizer']
    learning_rate = optimizer_config['learning_rate']
    weight_decay = optimizer_config.get('weight_decay', None)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    return optimizer

def _create_lr_scheduler(config, optimizer):
    lr_config = config.get('lr_scheduler', None)
    if lr_config is None:
        # use ReduceLROnPlateau as a default scheduler
        return ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=20, verbose=True)
    else:
        class_name = lr_config.pop('name')
        m = importlib.import_module('torch.optim.lr_scheduler')
        clazz = getattr(m, class_name)
        # add optimizer to the config
        lr_config['optimizer'] = optimizer
        return clazz(**lr_config)

# %%
# Create the model
model = get_model(config)
# put the model on GPUs
logger.info(f"Sending the model to '{config['device']}'")
model = model.to(config['device'])

# Log the number of learnable parameters
logger.info(f'Number of learnable params {get_number_of_learnable_parameters(model)}')

# Create loss criterion
loss_criterion = get_loss_criterion(config)

# Create evaluation metric
eval_criterion = get_evaluation_metric(config)

# Create the optimizer
optimizer = _create_optimizer(config, model)

# Create learning rate adjustment strategy
lr_scheduler = _create_lr_scheduler(config, optimizer)

# Create data loaders
loaders = get_train_loaders(config, c.train_patch_csv, c.val_patch_csv)

# Create model trainer
trainer = get_trainer(config)

# get tensorboard formatter
trainer_config = config['trainer']
tensorboard_formatter = get_tensorboard_formatter(trainer_config.get('tensorboard_formatter', None))

# Start training
trainer.fit(model=model, optimizer=optimizer, lr_scheduler=lr_scheduler, device=device, 
            loss_criterion=loss_criterion, eval_criterion=eval_criterion, loaders=loaders,
            logger=logger, checkpoint_dir = c.checkpointDir, tensorboard_formatter=tensorboard_formatter)
# Out:
# 2021-07-19 10:55:45,322 [MainThread] INFO VaryTrainer - Sending the model to 'cuda:0'
# 2021-07-19 10:55:47,308 [MainThread] INFO VaryTrainer - Number of learnable params 9484459
# 2021-07-19 10:55:47,310 [MainThread] INFO Prisma3TT1T2Dataset - Creating training and validation set loaders...
# 2021-07-19 10:55:47,310 [MainThread] INFO Prisma3TT1T2Dataset - Number of workers for train/val dataloader: 2
# 2021-07-19 10:55:47,311 [MainThread] INFO Prisma3TT1T2Dataset - Batch size for train loader: 3
# 2021-07-19 10:55:47,311 [MainThread] INFO Prisma3TT1T2Dataset - Batch size for validation loader: 6
# 2021-07-19 10:55:47,327 [MainThread] INFO VaryTrainer - eval_score_higher_is_better: True
# 2021-07-19 10:55:47,327 [MainThread] INFO VaryTrainer - LabelfusionUNet3DLabelWeightFineTunningUNetPerChannelSkipMaskCoordMapsBothDeepSupervision4LevelReLu(
#   (encoders): ModuleList(
#     (0): DownConv(
#       (conv1): Conv3d(7, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): DownConv(
#       (conv1): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): DownConv(
#       (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#     )
#   )
#   (decoders): ModuleList(
#     (0): UpConv(
#       (upconv): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (conv1): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): UpConv(
#       (upconv): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (conv1): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (norm): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (final_conv): Conv3d(32, 15, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   (inter_activation): Sigmoid()
#   (tunning_encoders): ModuleList(
#     (0): DownConv(
#       (conv1): Conv3d(18, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): DownConv(
#       (conv1): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): DownConv(
#       (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): DownConv(
#       (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (norm): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout3d(p=0.0, inplace=False)
#     )
#   )
#   (tunning_decoders): ModuleList(
#     (0): UpConv(
#       (upconv): ConvTranspose3d(256, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (conv1): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (norm): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): UpConv(
#       (upconv): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (conv1): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): UpConv(
#       (upconv): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (conv1): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (dropout): Dropout3d(p=0.0, inplace=False)
#       (norm): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (tunning_final_conv): Conv3d(32, 15, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   (tunning_ds_uplayers0): ModuleList(
#     (0): ConvTranspose3d(256, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     (1): ReLU()
#     (2): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     (3): ReLU()
#     (4): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     (5): ReLU()
#     (6): Conv3d(32, 15, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   )
#   (tunning_ds_uplayers1): ModuleList(
#     (0): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     (1): ReLU()
#     (2): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     (3): ReLU()
#     (4): Conv3d(32, 15, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   )
#   (tunning_ds_uplayers2): ModuleList(
#     (0): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     (1): ReLU()
#     (2): Conv3d(32, 15, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   )
#   (final_activation): Sigmoid()
# )
# 2021-07-19 10:55:47,598 [MainThread] INFO VaryTrainer - Training iteration 1. Batch 0. Epoch [0/19]
# 2021-07-19 10:55:50,717 [MainThread] INFO VaryTrainer - Training iteration 2. Batch 1. Epoch [0/19]
# 2021-07-19 10:55:53,970 [MainThread] INFO VaryTrainer - Training iteration 3. Batch 2. Epoch [0/19]
# 2021-07-19 10:55:57,583 [MainThread] INFO VaryTrainer - Training iteration 4. Batch 3. Epoch [0/19]
# 2021-07-19 10:56:01,451 [MainThread] INFO VaryTrainer - Training iteration 5. Batch 4. Epoch [0/19]
# 2021-07-19 10:56:04,749 [MainThread] INFO VaryTrainer - Training iteration 6. Batch 5. Epoch [0/19]
# 2021-07-19 10:56:07,912 [MainThread] INFO VaryTrainer - Training iteration 7. Batch 6. Epoch [0/19]
# 2021-07-19 10:56:11,727 [MainThread] INFO VaryTrainer - Training iteration 8. Batch 7. Epoch [0/19]
# 2021-07-19 10:56:15,560 [MainThread] INFO VaryTrainer - Training iteration 9. Batch 8. Epoch [0/19]
# 2021-07-19 10:56:18,802 [MainThread] INFO VaryTrainer - Training iteration 10. Batch 9. Epoch [0/19]
# 2021-07-19 10:56:27,467 [MainThread] INFO VaryTrainer - Training stats. Loss: 1.0283604919910432. Evaluation score: 0.8591499485596708
# invalid value encountered in true_divide
# 2021-07-19 10:56:28,194 [MainThread] INFO VaryTrainer - Training iteration 11. Batch 10. Epoch [0/19]
# 2021-07-19 10:56:31,352 [MainThread] INFO VaryTrainer - Training iteration 12. Batch 11. Epoch [0/19]
# 2021-07-19 10:56:34,979 [MainThread] INFO VaryTrainer - Validating...
# 2021-07-19 10:56:35,581 [MainThread] INFO VaryTrainer - Validation iteration 0
# 2021-07-19 10:56:44,087 [MainThread] INFO VaryTrainer - Validation iteration 1
# 2021-07-19 10:56:50,967 [MainThread] INFO VaryTrainer - Validation iteration 2
# 2021-07-19 10:56:58,483 [MainThread] INFO VaryTrainer - Validation iteration 3
# 2021-07-19 10:57:05,127 [MainThread] INFO VaryTrainer - Validation iteration 4
# 2021-07-19 10:57:11,894 [MainThread] INFO VaryTrainer - Validation iteration 5
# 2021-07-19 10:57:18,481 [MainThread] INFO VaryTrainer - Validation iteration 6
# 2021-07-19 10:57:25,143 [MainThread] INFO VaryTrainer - Validation iteration 7
# 2021-07-19 10:57:33,002 [MainThread] INFO VaryTrainer - Validation iteration 8
# 2021-07-19 10:57:39,893 [MainThread] INFO VaryTrainer - Validation iteration 9
# 2021-07-19 10:57:47,243 [MainThread] INFO VaryTrainer - Validation iteration 10
# 2021-07-19 10:57:54,702 [MainThread] INFO VaryTrainer - Validation iteration 11
# 2021-07-19 10:58:02,434 [MainThread] INFO VaryTrainer - Validation iteration 12
# 2021-07-19 10:58:09,560 [MainThread] INFO VaryTrainer - Validation iteration 13
# 2021-07-19 10:58:17,636 [MainThread] INFO VaryTrainer - Validation iteration 14
# 2021-07-19 10:58:24,432 [MainThread] INFO VaryTrainer - Validation iteration 15
# 2021-07-19 10:58:31,961 [MainThread] INFO VaryTrainer - Validation iteration 16
# 2021-07-19 10:58:38,502 [MainThread] INFO VaryTrainer - Validation iteration 17
# 2021-07-19 10:58:45,177 [MainThread] INFO VaryTrainer - Validation iteration 18
# 2021-07-19 10:58:51,732 [MainThread] INFO VaryTrainer - Validation iteration 19
# 2021-07-19 10:58:58,519 [MainThread] INFO VaryTrainer - Validation iteration 20
# 2021-07-19 10:59:05,421 [MainThread] INFO VaryTrainer - Validation iteration 21
# 2021-07-19 10:59:12,596 [MainThread] INFO VaryTrainer - Validation iteration 22
# 2021-07-19 10:59:20,701 [MainThread] INFO VaryTrainer - Validation iteration 23
# 2021-07-19 10:59:27,329 [MainThread] INFO VaryTrainer - Validation iteration 24
# 2021-07-19 10:59:34,858 [MainThread] INFO VaryTrainer - Validation iteration 25
# 2021-07-19 10:59:41,460 [MainThread] INFO VaryTrainer - Validation iteration 26
# 2021-07-19 10:59:48,421 [MainThread] INFO VaryTrainer - Validation iteration 27
# 2021-07-19 10:59:56,587 [MainThread] INFO VaryTrainer - Validation iteration 28
# 2021-07-19 11:00:03,426 [MainThread] INFO VaryTrainer - Validation iteration 29
# 2021-07-19 11:00:11,479 [MainThread] INFO VaryTrainer - Validation iteration 30
# 2021-07-19 11:00:18,344 [MainThread] INFO VaryTrainer - Validation iteration 31
# 2021-07-19 11:00:25,219 [MainThread] INFO VaryTrainer - Validation iteration 32
# 2021-07-19 11:00:31,981 [MainThread] INFO VaryTrainer - Validation iteration 33
# 2021-07-19 11:00:38,998 [MainThread] INFO VaryTrainer - Validation iteration 34
# 2021-07-19 11:00:46,598 [MainThread] INFO VaryTrainer - Validation iteration 35
# 2021-07-19 11:00:53,431 [MainThread] INFO VaryTrainer - Validation iteration 36
# 2021-07-19 11:01:01,440 [MainThread] INFO VaryTrainer - Validation iteration 37
# 2021-07-19 11:01:08,414 [MainThread] INFO VaryTrainer - Validation iteration 38
# 2021-07-19 11:01:15,257 [MainThread] INFO VaryTrainer - Validation iteration 39
# 2021-07-19 11:01:22,014 [MainThread] INFO VaryTrainer - Validation finished. Loss: 0.9253296613693237. Evaluation score: 0.8903797877014745
# 2021-07-19 11:01:22,045 [MainThread] INFO VaryTrainer - Saving new best evaluation metric: 0.8903797877014745
# 2021-07-19 11:01:22,046 [MainThread] INFO VaryTrainer - Saving last checkpoint to '/home/lxie/MultiModalDL//UNet/fold_0/model/run_601/last_checkpoint.pytorch'
# 2021-07-19 11:01:22,192 [MainThread] INFO VaryTrainer - Saving best checkpoint to '/home/lxie/MultiModalDL//UNet/fold_0/model/run_601/best_checkpoint.pytorch'
# 2021-07-19 11:01:22,253 [MainThread] INFO VaryTrainer - Training iteration 13. Batch 12. Epoch [0/19]
# 2021-07-19 11:01:25,899 [MainThread] INFO VaryTrainer - Training iteration 14. Batch 13. Epoch [0/19]
# 2021-07-19 11:01:29,806 [MainThread] INFO VaryTrainer - Training iteration 15. Batch 14. Epoch [0/19]
# 2021-07-19 11:01:33,080 [MainThread] INFO VaryTrainer - Training iteration 16. Batch 15. Epoch [0/19]
# 2021-07-19 11:01:36,242 [MainThread] INFO VaryTrainer - Training iteration 17. Batch 16. Epoch [0/19]
# 2021-07-19 11:01:40,000 [MainThread] INFO VaryTrainer - Training iteration 18. Batch 17. Epoch [0/19]
# 2021-07-19 11:01:43,769 [MainThread] INFO VaryTrainer - Training iteration 19. Batch 18. Epoch [0/19]
# 2021-07-19 11:01:46,927 [MainThread] INFO VaryTrainer - Training iteration 20. Batch 19. Epoch [0/19]
# 2021-07-19 11:01:54,832 [MainThread] INFO VaryTrainer - Training stats. Loss: 0.9166000425815582. Evaluation score: 0.8914332204503886
# 2021-07-19 11:01:55,564 [MainThread] INFO VaryTrainer - Training iteration 21. Batch 20. Epoch [0/19]
# 2021-07-19 11:01:58,869 [MainThread] INFO VaryTrainer - Training iteration 22. Batch 21. Epoch [0/19]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b85b731d2779> in <module>
#      31
#      32 # Start training
# ---> 33 trainer.fit(model=model, optimizer=optimizer, lr_scheduler=lr_scheduler, device=device,
#      34             loss_criterion=loss_criterion, eval_criterion=eval_criterion, loaders=loaders,
#      35             logger=logger, checkpoint_dir = c.checkpointDir, tensorboard_formatter=tensorboard_formatter)
#
# /data/lxie/MultiModalDL/UNet/python_code/model/trainer.py in fit(self, model, optimizer, lr_scheduler, loss_criterion, eval_criterion, device, loaders, checkpoint_dir, logger, tensorboard_formatter)
#    1090         for _ in range(self.num_epoch, self.max_num_epochs):
#    1091             # train for one epoch
# -> 1092             should_terminate = self.train(self.loaders['train'])
#    1093
#    1094             if should_terminate:
#
# /data/lxie/MultiModalDL/UNet/python_code/model/trainer.py in train(self, train_loader)
#    1137             #self.optimizer.zero_grad()
#    1138             #loss = loss / self.step_after_iters
# -> 1139             loss.backward()
#    1140
#    1141             #print('Update weight')
#
# /data/lxie/MultiModalDL/scripts/MONAI/.eggs/torch-1.8.1-py3.8-linux-x86_64.egg/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# /data/lxie/MultiModalDL/scripts/MONAI/.eggs/torch-1.8.1-py3.8-linux-x86_64.egg/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:
